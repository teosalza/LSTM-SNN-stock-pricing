# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#1-DAX
#2-BRAZILIAN
#3-NIKKEI
#4-SHANGAI

x = pd.DataFrame({
    "lstm": pd.Series({1: 43.53, 2: 53.45, 3:53.78,}), 
    "lstm gbrbm": pd.Series({1:50.73, 2:48.79, 3:56.40,4:54.88}),
    "gru": pd.Series({1:53.35, 2:52.55, 3:54.38,4:52.92}),
    "gru gbrbm": pd.Series({1:52.35, 2:54.95, 3:55.89,4:53.05})
    })

# %%
# Out:
#     lstm  lstm gbrbm    gru  gru gbrbm
# 1  43.53       50.73  53.35      52.35
# 2  53.45       48.79  52.55      54.95
# 3  53.78       56.40  54.38      55.89
# 4    NaN       54.88  52.92      53.05

# %%
x.index = ["DAX","IBOVESPA","NIKKEI 225","SSE"]
x.plot(kind="bar",ylim=(30, 60),figsize=(13,5),alpha=0.7,rot=0.5).legend(bbox_to_anchor=(1, 0.5))

# %%
#1-DAX
#2-BRAZILIAN
#3-NIKKEI
#4-SHANGAI

x2 = pd.DataFrame({
    "lstm": pd.Series({2: 53.55, 3:50.45,}), 
    "lstm gbrbm": pd.Series({1:46.38, 2:56.21, 3:54.35}),
    "gru": pd.Series({1:43.97, 2:55.33, 3:52.38,4:51.37}),
    "gru gbrbm": pd.Series({1:49.43, 2:50.59, 3:54.95,4:50.56})
    })

# %%
x2.index = ["DAX","IBOVESPA","NIKKEI 225","SSE"]
x2.plot(kind="bar",ylim=(30, 60),figsize=(13,5),alpha=0.7,rot=0.5).legend(bbox_to_anchor=(1, 0.5))
